# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from operator import attrgetter
import matplotlib.pyplot as plt
import heapq
from operator import itemgetter
from pydub import AudioSegment # for audio
from pydub.playback import play # for audio
from playsound import playsound # new

# %%
# file reading and sonification line by line

# %%
# method to quickly read from a file: from internet

# next: concatenate the audio files, to get only one file for each robot, and the sequence of notes

# I got x, z coordinates (called here x, y) as .txt from Webots + C

# add information on trash detection as an added sound or modified one in correspondence of trash
# (enrich the sound library in notes_)

with open('fx.txt', 'r') as fx:
    with open('fy.txt', 'r') as fy:
        linesx = (linex.strip() for linex in fx if linex)
        linesy = (liney.strip() for liney in fy if liney)
        x = [float(linex) for linex in linesx]
        y = [float(liney) for liney in linesy]
        for k in range(1,400):
            print(x[k], y[k])
         # sonification: here with inputs from -1 to 1
         # troubles with A#, D#, and C#: solved by changing the names: # --> _sharp
            if (x[k] == 0):
                if (y[k] == 0):
                    playsound("/Users/mariamannone/Desktop/xyz_robot/notes_/tC.mp3")
                    print("tC")
            if (x[k] > -1 and x[k] <= -0.6):
                if (y[k] < 0):
                    playsound("/Users/mariamannone/Desktop/xyz_robot/notes_/tB.mp3")
                    print("tB")
                if (y[k] >= 0):
                    playsound("/Users/mariamannone/Desktop/xyz_robot/notes_/tC_sharp.mp3")
                    print("tC#")
            if (x[k] > -0.6 and x[k] <= -0.3):
                if (y[k] < 0):
                    playsound("/Users/mariamannone/Desktop/xyz_robot/notes_/tA_sharp.mp3")
                    print("tA#")
                if (y[k] >= 0):
                    playsound("/Users/mariamannone/Desktop/xyz_robot/notes_/tD.mp3")
                    print("tD")
            if (x[k] > -0.3 and x[k] <= 0):
                if (y[k] < 0):
                    playsound("/Users/mariamannone/Desktop/xyz_robot/notes_/tD_sharp.mp3")
                    print("tD#")
                if (y[k] >= 0):
                    playsound("/Users/mariamannone/Desktop/xyz_robot/notes_/tA.mp3")
                    print("tA")
            if (x[k] > 0 and x[k] <= 0.3):
                if (y[k] < 0):
                    playsound("/Users/mariamannone/Desktop/xyz_robot/notes_/tE.mp3")
                    print("tE")
                if (y[k] >= 0):
                    playsound("/Users/mariamannone/Desktop/xyz_robot/notes_/tG_sharp.mp3")
                    print("tG#")
            if (x[k] > 0.3 and x[k] <= 0.6):
                if (y[k] < 0):
                    playsound("/Users/mariamannone/Desktop/xyz_robot/notes_/tF.mp3")
                    print("tF")
                if (y[k] >= 0):
                    playsound("/Users/mariamannone/Desktop/xyz_robot/notes_/tG.mp3")
                    print("tG")
            if (x[k] > 0.6 and x[k] <= 1):
                playsound("/Users/mariamannone/Desktop/xyz_robot/notes_/tF_sharp.mp3")
                print("tF#")
# Out:
# 0.49996 0.17504
# tG
# 0.49983 0.17517
# tG
# 0.499545 0.175455
# tG
# 0.499024 0.175976
# tG
# 0.498175 0.176827
# tG
# 0.496895 0.178107
# tG
# 0.49508 0.179924
# tG
# 0.49262 0.182386
# tG
# 0.48941 0.185598
# tG
# 0.485347 0.189664
# tG
# 0.480338 0.194677
# tG
# 0.474297 0.200724
# tG
# 0.467148 0.207878
# tG
# 0.460049 0.214984
# tG
# 0.452997 0.222041
# tG
# 0.445994 0.22905
# tG
# 0.439038 0.236012
# tG
# 0.43213 0.242926
# tG
# 0.425269 0.249793
# tG
# 0.418454 0.256613
# tG
# 0.411686 0.263387
# tG
# 0.404964 0.270115
# tG
# 0.398288 0.276797
# tG
# 0.391658 0.283433
# tG
# 0.385072 0.290024
# tG
# 0.378531 0.296571
# tG
# 0.372035 0.303072
# tG
# 0.365583 0.30953
# tG
# 0.359175 0.315943
# tG
# 0.352811 0.322313
# tG
# 0.34649 0.328639
# tG
# 0.340212 0.334922
# tG
# 0.333977 0.341163
# tG
# 0.327784 0.347361
# tG
# 0.321634 0.353516
# tG
# 0.315525 0.35963
# tG
# 0.309458 0.365702
# tG
# 0.303432 0.371733
# tG
# 0.297447 0.377723
# tG#
# 0.291503 0.383672
# tG#
# ...

# %%
# and an added sound for the trash detection, even a small cluster or a sound effect...
